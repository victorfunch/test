# %%
# Irrelevantntntntntn
# bla bæla

# %%
import pandas as pd

# %%
a = pd.read_csv('arb_bra_disco_erfaring_civil.txt', sep='\t', encoding='latin1')
a.head()
# Out:
#                    arb_reg        udd_niv       udd_retning  \
# 0  Hovedstaden og Sjælland  Civilingeniør  Byggeri og anlæg
# 1  Hovedstaden og Sjælland  Civilingeniør  Byggeri og anlæg
# 2  Hovedstaden og Sjælland  Civilingeniør  Byggeri og anlæg
# 3  Hovedstaden og Sjælland  Civilingeniør  Byggeri og anlæg
# 4  Hovedstaden og Sjælland  Civilingeniør  Byggeri og anlæg
#
#                         IDA_branche                            IDA_grp  \
# 0                        Rådgivning                   Byggeri og anlæg
# 1  IT, information og kommunikation                     IT - udvikling
# 2                        Rådgivning                   Byggeri og anlæg
# 3  IT, information og kommunikation  IT - Projektstyring og forretning
# 4                        Rådgivning                   Byggeri og anlæg
#
#   erfaring  N_personer
# 0   10+ år        3077
# 1   10+ år        1272
# 2  5-10 år         896
# 3   10+ år         845
# 4   2-5 år         733

# %%
b = pd.read_csv('arb_bra_disco_erfaring_ikkecivil.txt', sep='\t', encoding='latin1')
b.head()
# Out:
#                    arb_reg           udd_niv  \
# 0  Hovedstaden og Sjælland      Cand.scient.
# 1  Hovedstaden og Sjælland      Cand.scient.
# 2  Hovedstaden og Sjælland         Ph.d, Dr.
# 3  Hovedstaden og Sjælland  Teknikumingeniør
# 4  Hovedstaden og Sjælland         Ph.d, Dr.
#
#                                          udd_retning  \
# 0  Fysik, Nanoteknologi, Geografik, Geologi, Mate...
# 1     Bioloigi, Bioteknologi, Sundhed, Lægevidenskab
# 2  Fysik, Nanoteknologi, Geografik, Geologi, Mate...
# 3                    Elektronik, Stærk- og Svagstrøm
# 4  Maskin, Mekanik, Inudstriproduktion, Robot, Sk...
#
#                            IDA_branche  \
# 0  Akademisk undervisning og forksning
# 1  Akademisk undervisning og forksning
# 2  Akademisk undervisning og forksning
# 3                           Rådgivning
# 4  Akademisk undervisning og forksning
#
#                                     IDA_grp erfaring  N_personer
# ...

# %%
c = pd.concat([a, b], ignore_index=True).sort_values('N_personer', ascending=False)

# %%
c.to_excel('tilAH.xlsx', index=False)
